# %% [markdown]
# # 保存和加载图片

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']  # matplotlib加入中文支持

# %% [markdown]
# ## 保存图片

# %%
plt.plot(np.random.rand(10), np.random.rand(10))
"""
保存图片
dpi指示图片分辨率
可保存为png、svg(矢量)、pdf(矢量)等格式
"""
plt.savefig("save_sample.svg", dpi=300, format="svg")

# %% [markdown]
# ## 加载图片

# %%
img = plt.imread("./line_styles_reference.png") # 不支持加载svg格式
plt.imshow(img)
plt.show()
